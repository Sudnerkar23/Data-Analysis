# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
raw_data = pd.read_csv("Marketing Raw Data.csv",encoding = "cp1252")#IS0-8859--1
raw_data
# Out:
#            Date   Day_Name  Visitors  Revenue  Marketing Spend           Promo
# 0    09/11/2020     Monday       707     5211       651.375000        No Promo
# 1    10/11/2020    Tuesday      1455    10386      1298.250000   Promotion Red
# 2    11/11/2020  Wednesday      1520    12475      1559.375000  Promotion Blue
# 3    12/11/2020   Thursday      1726    14414      1801.750000        No Promo
# 4    13/11/2020     Friday      2134    20916      2614.500000        No Promo
# ..          ...        ...       ...      ...              ...             ...
# 177  05/05/2021  Wednesday      1400    11196      1119.600000        No Promo
# 178  06/05/2021   Thursday      2244    18611      2067.888889   Promotion Red
# 179  07/05/2021     Friday      2023    14502      1450.200000        No Promo
# 180  08/05/2021   Saturday      1483     8975      1121.875000        No Promo
# 181  09/05/2021     Sunday      1303     6968       871.000000        No Promo
#
# [182 rows x 6 columns]

# %%
print(raw_data.shape)
# Out:
# (182, 6)

# %%
raw_data.head()
# Out:
#          Date   Day_Name  Visitors  Revenue  Marketing Spend           Promo
# 0  09/11/2020     Monday       707     5211          651.375        No Promo
# 1  10/11/2020    Tuesday      1455    10386         1298.250   Promotion Red
# 2  11/11/2020  Wednesday      1520    12475         1559.375  Promotion Blue
# 3  12/11/2020   Thursday      1726    14414         1801.750        No Promo
# 4  13/11/2020     Friday      2134    20916         2614.500        No Promo

# %%
raw_data.head(10)
# Out:
#          Date   Day_Name  Visitors  Revenue  Marketing Spend           Promo
# 0  09/11/2020     Monday       707     5211       651.375000        No Promo
# 1  10/11/2020    Tuesday      1455    10386      1298.250000   Promotion Red
# 2  11/11/2020  Wednesday      1520    12475      1559.375000  Promotion Blue
# 3  12/11/2020   Thursday      1726    14414      1801.750000        No Promo
# 4  13/11/2020     Friday      2134    20916      2614.500000        No Promo
# 5  14/11/2020   Saturday      1316    12996      1444.000000  Promotion Blue
# 6  15/11/2020     Sunday      1287    11929      1325.444444  Promotion Blue
# 7  16/11/2020     Monday      1548    10072      1119.111111        No Promo
# 8  17/11/2020    Tuesday      1448    12016      1092.363636  Promotion Blue
# 9  18/11/2020  Wednesday      1362     9067       906.700000        No Promo

# %%
raw_data.tail(10)
# Out:
#            Date   Day_Name  Visitors  Revenue  Marketing Spend           Promo
# 172  30/04/2021     Friday      1836    19167      1916.700000  Promotion Blue
# 173  01/05/2021   Saturday      1380     8862       805.636364        No Promo
# 174  02/05/2021     Sunday      1423    12111      1513.875000   Promotion Red
# 175  03/05/2021     Monday      1382    11273      1024.818182   Promotion Red
# 176  04/05/2021    Tuesday      2152    13805      1533.888889        No Promo
# 177  05/05/2021  Wednesday      1400    11196      1119.600000        No Promo
# 178  06/05/2021   Thursday      2244    18611      2067.888889   Promotion Red
# 179  07/05/2021     Friday      2023    14502      1450.200000        No Promo
# 180  08/05/2021   Saturday      1483     8975      1121.875000        No Promo
# 181  09/05/2021     Sunday      1303     6968       871.000000        No Promo

# %%
# %matplotlib inline
plt.bar(raw_data["Visitors"],raw_data['Revenue'],color='yellow',width=5)
plt.title("visitors vs revenue")
plt.xlabel('Visitor')
plt.ylabel('Revenue')
plt.show()
plt.savefig("./1visitor vs revenue")

# %%
# %matplotlib inline
plt.plot(raw_data['Day_Name'], color='green', linestyle='-.',label='Day_N')
plt.plot(raw_data['Visitors'], linewidth=1., label='Visitors')
#plt.plot(raw_data['Revenue'], color='red', linestyle ='--',label= 'Revenue')
plt.title("Marketing",fontsize=20, fontweight="bold")
plt.legend(loc="upper left",fontsize=15)
#plt.xticks(['Day_Name'],'Jan','Feb','Mar','Apr','May')
plt.xlabel('Day_N')
plt.ylabel('Visitors')
plt.show()

# %%
plt.plot(raw_data['Visitors'], linewidth=1., label='Visitors')
plt.show()

# %%
plt.plot(raw_data['Visitors']

# %%
a = raw_data.tail(10).reset_index()
plt.plot(a['Visitors'])
plt.plot(a['Revenue'],linestyle="-.")
plt.xticks(range(0,len(a["Visitors"])), a["Date"], rotation = 90)
plt.xticks(range(0,len(a["Revenue"])), a["Date"], rotation = 90)

plt.show()

# %%
# combo stack bars
#Combo stack bars


plt.figure(figsize=(15,10))
plt.bar(range(0,len(a["Revenue"])), a["Revenue"], label="Revenue", linewidth=5., color = "green")
plt.bar(range(0,len(a["Visitors"])), a["Marketing Spend"], label="Marketing Spend", linewidth=5., color = "red")

#plt.plot(a["Visitors"], linestyle = "-.")

plt.xticks(range(0,len(a["Visitors"])), a["Date"], rotation = 90)
plt.title("Visitors & Revenue by Day", fontsize = 20)
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Dates")
plt.show()

# %%
#Combo 2+ bar graphs + Secondary Scale

weight = .50

a[["Revenue", "Marketing Spend"]].plot(kind="bar", color = ["green", "red"], figsize=(20,10))
a["Visitors"].plot(c="blue", linestyle = "-", secondary_y=True)

plt.xticks(range(0,len(a["Visitors"])), a["Date"],rotation=90)
plt.title("Visitors & Revenue by Day", fontsize = 20)
plt.legend(loc="upper left", fontsize=14)
plt.xlabel("Dates")
plt.xlim(-weight, len(a["Visitors"])-weight)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.scatter(raw_data["Revenue"], raw_data["Marketing Spend"], c="red",marker='*',s=500,alpha=0.2)
plt.title("Relationship between M. Spend & Revenue", fontsize = 20)
# plt.legend(loc="upper left", fontsize=14)
plt.xlabel("Revenue")
plt.ylabel("Marketing Spend")

plt.show()

# %%
#Scatterplot with groups

groups = raw_data[["Promo","Revenue","Marketing Spend"]].groupby("Promo")
groups

fig, ax = plt.subplots(figsize=(15,10))

for promo, group in groups:
    ax.scatter(group['Revenue'], group['Marketing Spend'], marker = 'x', label=promo)

ax.legend()
plt.title("Relationship between M. Spend & Revenue by Promo", fontsize = 20)
plt.xlabel("Revenue")
plt.ylabel("Marketing Spend")

plt.show()
